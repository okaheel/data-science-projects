# %% [markdown]
# # Assignment 9 (10 Points): Matplotlib

# %%
import numpy as np
import pandas as pd
import sklearn.cluster

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.style.use('classic')
mpl.rc("figure", facecolor="white")
import seaborn as sns
sns.set()
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
iris = sns.load_dataset("iris")
iris.head()
iris = iris.rename(columns={'sepal_length': 'Sepal length (cm)'})
iris = iris.rename(columns={'sepal_width': 'Sepal width (cm)'})
iris = iris.rename(columns={'petal_length': 'Petal length (cm)'})
iris = iris.rename(columns={'petal_width': 'Petal width (cm)'})
iris = iris.rename(columns={'Species': 'species'})
iris
# Out:
#      Sepal length (cm)  Sepal width (cm)  Petal length (cm)  Petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %% [markdown]
# ### Q1 (5 points): Reverse engineer the following figure. You are not allowed to use the seaborn commands (e.g., pairplot). Hint: Use the following commands from matplotlib and python:
# ```
# subplots
# groupby
# for (you might need to use upto three for loops)
# if
# else
# scatter
# set_xlabel
# set_ylabel
# legend
# ```

# %%
estimator = sklearn.cluster.KMeans(n_clusters=3)
estimator.fit(iris[['Sepal length (cm)', 'Sepal width (cm)', 'Petal length (cm)', 'Petal width (cm)']])
iris['K-means cluster assignment'] = estimator.labels_

# %%
sns.pairplot(iris, hue='species', size=2.5);

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import numpy as np

#included broken for loop implementation below, loops through first round correctly then breaks on second row
#couldn't figure out which style was used for these

layout = {'Sepal length (cm)' : 0,
          'Sepal width (cm)' : 1,
          'Petal length (cm)' : 2,
          'Petal width (cm)' : 3,
}


fig, axs = plt.subplots(ncols=4, nrows=4, figsize=(12, 12))
            
sns.scatterplot(x="Sepal width (cm)", y="Sepal length (cm)", data=iris, ax=axs[0, 1], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Petal length (cm)", y="Sepal length (cm)", data=iris, ax=axs[0, 2], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Petal width (cm)", y="Sepal length (cm)", data=iris, ax=axs[0, 3], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)

sns.scatterplot(x="Sepal length (cm)", y="Sepal width (cm)", data=iris, ax=axs[1, 0], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Petal length (cm)", y="Sepal width (cm)", data=iris, ax=axs[1, 2], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Petal width (cm)", y="Sepal width (cm)", data=iris, ax=axs[1, 3], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)

sns.scatterplot(x="Sepal length (cm)", y="Petal length (cm)", data=iris, ax=axs[2, 0], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Sepal width (cm)", y="Petal length (cm)", data=iris, ax=axs[2, 1], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Petal width (cm)", y="Petal length (cm)", data=iris, ax=axs[2, 3], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)

sns.scatterplot(x="Sepal length (cm)", y="Petal width (cm)", data=iris, ax=axs[3, 0], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Sepal width (cm)", y="Petal width (cm)", data=iris, ax=axs[3, 1], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
sns.scatterplot(x="Petal length (cm)", y="Petal width (cm)", data=iris, ax=axs[3, 2], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)

import matplotlib.patches as mpatches
import matplotlib.lines as mlines

palette = sns.color_palette()
setosa = mpatches.Patch(color=palette[0], label='Iris setosa', alpha=0.5)
versicolor = mpatches.Patch(color=palette[1], label='Iris versicolor', alpha=0.5)
virginica = mpatches.Patch(color=palette[2], label='Iris virginica', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c0870c3dfec1> in <module>
#      15 fig, axs = plt.subplots(ncols=4, nrows=4, figsize=(12, 12))
#      16
# ---> 17 sns.scatterplot(x="Sepal width (cm)", y="Sepal length (cm)", data=iris, ax=axs[0, 1], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
#      18 sns.scatterplot(x="Petal length (cm)", y="Sepal length (cm)", data=iris, ax=axs[0, 2], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
#      19 sns.scatterplot(x="Petal width (cm)", y="Sepal length (cm)", data=iris, ax=axs[0, 3], hue="Species", style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
#
# ...

# %%
#broken for loop implementation
layout = {'Sepal length (cm)' : 0,
          'Sepal width (cm)' : 1,
          'Petal length (cm)' : 2,
          'Petal width (cm)' : 3,
}


fig, axs = plt.subplots(ncols=4, nrows=4, figsize=(12, 12))

for column in iris:
    for row in iris:
        if(row != column):
            sns.scatterplot(x=row, y=column, data=iris, ax=axs[layout[column], layout[row]], hue="species", 
                            style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)


import matplotlib.patches as mpatches
import matplotlib.lines as mlines

palette = sns.color_palette()
setosa = mpatches.Patch(color=palette[0], label='Iris setosa', alpha=0.5)
versicolor = mpatches.Patch(color=palette[1], label='Iris versicolor', alpha=0.5)
virginica = mpatches.Patch(color=palette[2], label='Iris virginica', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-6110e9627e8e> in <module>
#      12     for row in iris:
#      13         if(row != column):
# ---> 14             sns.scatterplot(x=row, y=column, data=iris, ax=axs[layout[column], layout[row]], hue="species",
#      15                             style="K-means cluster assignment", legend=False, marker="x", alpha=0.5)
#      16
#
# KeyError: 'species'

# %% [markdown]
# ### Q2 (2.5 points): Use the seaborn package to generate the following plot.

# %%
iris = sns.load_dataset('iris')
iris.head()


with sns.axes_style('white'):
    sns.jointplot("sepal_length", "sepal_width", data=iris, kind='hex')

# %% [markdown]
# ### Q3 (2.5 points): Use the matplotlib package to generate the following plot.

# %%
births = pd.read_csv('data-sources/births.csv')

# %%
sns.set()  # use Seaborn styles
births.pivot_table('births', index='year', columns='gender', aggfunc='sum').plot()
plt.ylabel('total births per year');

quartiles = np.percentile(births['births'], [25, 50, 75])
mu = quartiles[1]
sig = 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')
births['day'] = births['day'].astype(int)
births.index = pd.to_datetime(10000 * births.year +
                              100 * births.month +
                              births.day, format='%Y%m%d')

births['dayofweek'] = births.index.dayofweek

# %%
births
# Out:
#             year  month  day gender  births  dayofweek
# 1969-01-01  1969      1    1      F    4046          2
# 1969-01-01  1969      1    1      M    4440          2
# 1969-01-02  1969      1    2      F    4454          3
# 1969-01-02  1969      1    2      M    4548          3
# 1969-01-03  1969      1    3      F    4548          4
# ...          ...    ...  ...    ...     ...        ...
# 1988-12-29  1988     12   29      M    5944          3
# 1988-12-30  1988     12   30      F    5742          4
# 1988-12-30  1988     12   30      M    6095          4
# 1988-12-31  1988     12   31      F    4435          5
# 1988-12-31  1988     12   31      M    4698          5
#
# [14610 rows x 6 columns]

# %%
births_by_date = births.pivot_table('births', 
                                    [births.index.month, births.index.day])
births_by_date.head()
births_by_date.index = [pd.datetime(2012, month, day)
                        for (month, day) in births_by_date.index]
births_by_date.head()
# Out:
#               births
# 2012-01-01  4009.225
# 2012-01-02  4247.400
# 2012-01-03  4500.900
# 2012-01-04  4571.350
# 2012-01-05  4603.625

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax);

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# Add labels to the plot
ax.annotate("New Year's Day", xy=('2012-1-1', 4100),  xycoords='data',
            xytext=(50, -30), textcoords='offset points',
            arrowprops=dict(arrowstyle="->", color = 'black',
                            connectionstyle="arc3,rad=-0.2"))

ax.annotate("Independence Day", xy=('2012-7-4', 4250),  xycoords='data',
            bbox=dict(boxstyle="round", fc="none", ec="gray"),
            xytext=(10, -40), textcoords='offset points', ha='center',
            arrowprops=dict(arrowstyle="->", color = 'black'))

ax.annotate('Labor Day', xy=('2012-9-4', 4850), xycoords='data', ha='center',
            xytext=(0, -20), textcoords='offset points')
ax.annotate('', xy=('2012-9-1', 4850), xytext=('2012-9-7', 4850),
            xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2' })

ax.annotate('Halloween', xy=('2012-10-31', 4600),  xycoords='data',
            xytext=(-80, -40), textcoords='offset points',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('Thanksgiving', xy=('2012-11-25', 4500),  xycoords='data',
            xytext=(-120, -60), textcoords='offset points',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9", color = 'black'),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle,angleA=0,angleB=80,rad=20", color = 'black'))


ax.annotate('Christmas', xy=('2012-12-25', 3850),  xycoords='data',
             xytext=(-30, 0), textcoords='offset points',
             size=13, ha='right', va="center",
             bbox=dict(boxstyle="round", alpha=0.1),
             arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1));

# Label the axes
ax.set(title='USA births by day of year (1969-1988)',
       ylabel='average daily births')

# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));



ax.set_ylim(3600, 5400);
